# %%
# %matplotlib inline
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
mesi = cv.imread("../image/mesi.jpg")

# %%
plt.figure(figsize=(8,10))

baru = lambda x: [[[k[2],k[1],k[0]]for k in i]for i in x]


plt.imshow(baru(mesi))
plt.show()

# %%
np.array([12,2,2]) + np.array([12,2,2])
# Out:
# array([24,  4,  4])

# %%
cv.imshow("hore",mesi)
cv.waitKey(30000)
cv.destroyWindow("hore")
